# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATASET.csv')
df.head()
# Out:
#    Age  Credit_Score  Account_Balence  Credit_Card_Holter  Dependents  \
# 0   86           451           825749                   1           1
# 1   64           465           140667                   0           0
# 2   65           409           716824                   0           2
# 3   57           446           323539                   0           2
# 4   67           475           973045                   1           2
#
#   Employment_Type  Applicant_Income  Coapplicant_Income  Loan_Status  \
# 0        Employed            128630               81915            0
# 1        Employed             75633               78479            1
# 2   Self_Employed            178202              174249            0
# 3        Employed            180802               96209            1
# 4        Employed             80110               25057            1
#
#   Education_Status  Fidelity_Scores
# 0        Graduated               51
# 1        Graduated               59
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Credit_Score', 'Account_Balence', 'Credit_Card_Holter',
#        'Dependents', 'Employment_Type', 'Applicant_Income',
#        'Coapplicant_Income', 'Loan_Status', 'Education_Status',
#        'Fidelity_Scores'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Employment_Type',"Education_Status"]
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Education_Status',data=df, color='yellow')
# Out:
# <Axes: xlabel='Education_Status', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Credit_Card_Holter'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Dependents'],color='blue')
# Out:
# (array([6616.,    0.,    0.,    0.,    0., 6654.,    0.,    0.,    0.,
#         6730.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='green')
plt.show()

# %%
df['Employment_Type'].hist(figsize=(10,5),color='yellow')
# Out:
# <Axes: >

# %%
sns.lineplot(df['Credit_Card_Holter'], color='brown') # scatter, plot, triplot, stackplot
# Out:
# <Axes: ylabel='Credit_Card_Holter'>

# %%
sns.violinplot(df['Dependents'], color='purple')
# Out:
# <Axes: ylabel='Dependents'>

# %%
df['Education_Status'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['Credit_Card_Holter'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.displot(df['Dependents'], color='coral') # residplot, scatterplot

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Education_Status')
# Out:
# Education_Status
# 0    50.26
# 1    49.74
# Name: count, dtype: float64
